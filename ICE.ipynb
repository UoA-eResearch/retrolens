# %%
import pandas as pd  # Tabular data
from glob import glob  # File pattern matching
import os  # Operating System
import geopandas as gpd  # Geospatial data
import re  # Regular expressions
import math
from tqdm.auto import tqdm  # Progress bars
from tqdm.contrib.concurrent import thread_map, process_map  # Parallel operations
import rapidfuzz # Fuzzy string matching

pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", 130)

import platform
if platform.system() == "Windows":
  prefix = "Z:/"
else:
  prefix = "ressci201900060-RNC2-Coastal/"

df = pd.concat(pd.read_csv(f) for f in ["meta.csv", "LDS_meta.csv"])
# Filter to just shapefiles that have the CRS column defined
df = df[df.CPS & (df.n_lines > 0)]
df["Pixel_ER"] = (
    df.res.str.replace("(", "", regex=False).str.split(",").str[0].astype(float)
)
df
# Out:
#                                                                              filename  \
# 0            MaxarImagery/HighFreq/HawkesBay/Mahanga/Shorelines/Mahanga_31AUG2005.shp
# 1                 Retrolens/Tasman/MoutereRiver/Shorelines/MoutereRiver_19FEB2010.shp
# 2                 Retrolens/Tasman/MoutereRiver/Shorelines/MoutereRiver_31JAN1980.shp
# 3                 Retrolens/Tasman/MoutereRiver/Shorelines/MoutereRiver_10AUG2003.shp
# 4                 Retrolens/Tasman/MoutereRiver/Shorelines/MoutereRiver_19APR2017.shp
# ..                                                                                ...
# 51              Retrolens/Bay of Plenty/WaihiBeach/Shorelines/WaihiBeach_3DEC2014.shp
# 52               Retrolens/Bay of Plenty/PortOhope/Shorelines/OhopeBeach_3DEC2014.shp
# 53                        Retrolens/Bay of Plenty/Ohiwa/Shorelines/Ohiwa_3DEC2014.shp
# 54               Retrolens/Bay of Plenty/PortOhope/Shorelines/OhopeBeach_3DEC2014.shp
# 55  MaxarImagery/HighFreq/Wellington/KapitiNorth/Shorelines/NorthKapiti_15MAR2017.shp
#
#                                                                          matched_image  \
# 0          MaxarImagery/HighFreq/HawkesBay/Mahanga/Imagery/Stack/Mahanga_31AUG2005.tif
# 1   MaxarImagery/HighFreq/Tasman/MoutereRiver/Imagery/Stack/MoutereRiver_19FEB2010.tif
# 2                Retrolens/Tasman/MoutereRiver/Stack/MoutereRiver_31JAN1980_mosaic.jp2
# 3   MaxarImagery/HighFreq/Tasman/MoutereRiver/Imagery/Stack/MoutereRiver_10AUG2003.tif
# 4   MaxarImagery/HighFreq/Tasman/MoutereRiver/Imagery/Stack/MoutereRiver_19APR2017.tif
# ..                                                                                 ...
# 51               Retrolens/Bay of Plenty/WaihiBeach/Shorelines/WaihiBeach_3DEC2014.tif
# 52                Retrolens/Bay of Plenty/PortOhope/Shorelines/OhopeBeach_3DEC2014.tif
# 53                         Retrolens/Bay of Plenty/Ohiwa/Shorelines/Ohiwa_3DEC2014.tif
# 54                Retrolens/Bay of Plenty/PortOhope/Shorelines/OhopeBeach_3DEC2014.tif
# 55   MaxarImagery/HighFreq/Wellington/KapitiNorth/Shorelines/NorthKapiti_15MAR2017.tif
#
#     match_score  n_lines       driver   dtype  nodata  width  height  count  \
# 0         100.0        2        GTiff   uint8     NaN   3975   12039      3
# 1         100.0        7        GTiff   uint8     NaN   7839   13469      3
# 2         100.0        4  JP2OpenJPEG  uint16   256.0   4917    6845      3
# 3         100.0        8        GTiff   uint8     NaN   7839   13469      3
# 4         100.0        5        GTiff   uint8     NaN   9408   16163      3
# ..          ...      ...          ...     ...     ...    ...     ...    ...
# 51        100.0        7        GTiff   uint8     NaN  38400   63360      3
# 52        100.0        5        GTiff   uint8     NaN  88320   40320      3
# 53        100.0        1        GTiff   uint8     NaN  38400   11520      3
# 54        100.0        5        GTiff   uint8     NaN  88320   40320      3
# 55        100.0        6        GTiff   uint8     NaN  24000   36000      3
#
#                                                                                                                                   crs  \
# 0                                                                                                                                 NaN
# 1   PROJCS["NZGD2000 / New Zealand Transverse Mercator 2000",GEOGCS["NZGD2000",DATUM["New_Zealand_Geodetic_Datum_2000",SPHEROID["G...
# 2   PROJCS["NZGD2000 / New Zealand Transverse Mercator 2000",GEOGCS["NZGD2000",DATUM["New_Zealand_Geodetic_Datum_2000",SPHEROID["G...
# 3   PROJCS["NZGD2000 / New Zealand Transverse Mercator 2000",GEOGCS["NZGD2000",DATUM["New_Zealand_Geodetic_Datum_2000",SPHEROID["G...
# 4   PROJCS["NZGD2000 / New Zealand Transverse Mercator 2000",GEOGCS["NZGD2000",DATUM["New_Zealand_Geodetic_Datum_2000",SPHEROID["G...
# ..                                                                                                                                ...
# 51                                                                                                                          EPSG:2193
# 52                                                                                                                          EPSG:2193
# 53                                                                                                                          EPSG:2193
# 54                                                                                                                          EPSG:2193
# 55                                                                                                                          EPSG:2193
#
#                                                                     transform  \
# 0   | 0.60, 0.00, 2022707.13|\n| 0.00,-0.60, 5670278.45|\n| 0.00, 0.00, 1.00|
# 1   | 0.60, 0.00, 1602120.79|\n| 0.00,-0.60, 5446080.72|\n| 0.00, 0.00, 1.00|
# 2   | 1.40, 0.00, 1600979.23|\n| 0.00,-1.40, 5447041.85|\n| 0.00, 0.00, 1.00|
# 3   | 0.60, 0.00, 1602120.79|\n| 0.00,-0.60, 5446080.72|\n| 0.00, 0.00, 1.00|
# 4   | 0.50, 0.00, 1602120.69|\n| 0.00,-0.50, 5446080.83|\n| 0.00, 0.00, 1.00|
# ..                                                                        ...
# 51  | 0.12, 0.00, 1859680.00|\n| 0.00,-0.12, 5857440.00|\n| 0.00, 0.00, 1.00|
# 52  | 0.12, 0.00, 1953280.00|\n| 0.00,-0.12, 5791920.00|\n| 0.00, 0.00, 1.00|
# 53  | 0.12, 0.00, 1964800.00|\n| 0.00,-0.12, 5787600.00|\n| 0.00, 0.00, 1.00|
# 54  | 0.12, 0.00, 1953280.00|\n| 0.00,-0.12, 5791920.00|\n| 0.00, 0.00, 1.00|
# 55  | 0.30, 0.00, 1770400.00|\n| 0.00,-0.30, 5485200.00|\n| 0.00, 0.00, 1.00|
#
#     blockxsize  blockysize  tiled compress interleave  GCPs  \
# 0        128.0         128   True      lzw      pixel    26
# 1        128.0         128   True      lzw      pixel     0
# 2       1024.0        1024   True      NaN      pixel     0
# 3        128.0         128   True      lzw      pixel     0
# 4        128.0         128   True      lzw      pixel     0
# ..         ...         ...    ...      ...        ...   ...
# 51         NaN           1  False      lzw      pixel     0
# 52         NaN           1  False      lzw      pixel     0
# 53         NaN           1  False      lzw      pixel     0
# 54         NaN           1  False      lzw      pixel     0
# 55         NaN           1  False      lzw      pixel     0
#
#                                          res   CPS photometric  \
# 0                  (0.6, 0.5999999999999536)  True         NaN
# 1   (0.6000000000000179, 0.6000000000000276)  True         NaN
# 2   (1.3997952365892727, 1.3997952365892659)  True         NaN
# 3   (0.6000000000000179, 0.6000000000000276)  True         NaN
# 4                                 (0.5, 0.5)  True         NaN
# ..                                       ...   ...         ...
# 51                            (0.125, 0.125)  True         NaN
# 52                            (0.125, 0.125)  True         NaN
# 53                            (0.125, 0.125)  True         NaN
# 54                            (0.125, 0.125)  True         NaN
# 55                                (0.3, 0.3)  True         NaN
#
#                                   matched_tile_root  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ..                                              ...
# 51                   DigitalJPGs/BayOfPlenty/BOP14U
# 52                   DigitalJPGs/BayOfPlenty/BOP14U
# 53                   DigitalJPGs/BayOfPlenty/BOP14U
# 54                   DigitalJPGs/BayOfPlenty/BOP14U
# 55  DigitalJPGs/Wellington/Wellington Rural 2016-17
#
#                                                                      matched_filename  \
# 0                                                                                 NaN
# 1                                                                                 NaN
# 2                                                                                 NaN
# 3                                                                                 NaN
# 4                                                                                 NaN
# ..                                                                                ...
# 51              Retrolens/Bay of Plenty/WaihiBeach/Shorelines/WaihiBeach_3DEC2014.shp
# 52               Retrolens/Bay of Plenty/PortOhope/Shorelines/OhopeBeach_3DEC2014.shp
# 53                        Retrolens/Bay of Plenty/Ohiwa/Shorelines/Ohiwa_3DEC2014.shp
# 54               Retrolens/Bay of Plenty/PortOhope/Shorelines/OhopeBeach_3DEC2014.shp
# 55  MaxarImagery/HighFreq/Wellington/KapitiNorth/Shorelines/NorthKapiti_15MAR2017.shp
#
#     Pixel_ER
# 0   0.600000
# 1   0.600000
# 2   1.399795
# 3   0.600000
# 4   0.500000
# ..       ...
# 51  0.125000
# 52  0.125000
# 53  0.125000
# 54  0.125000
# 55  0.300000
#
# [1185 rows x 24 columns]

# %%
def get_lines(filename):
    try:
        gdf = gpd.read_file(prefix + filename)
    except Exception as e:
        print(e)
        return pd.NA
    return len(gdf.explode(index_parts=False))

df["n_lines_now"] = thread_map(get_lines, df.filename)
# Out:
# ressci201900060-RNC2-Coastal/Retrolens/Canterbury/GoochBay/Shorelines/GoochBay_10DEC1942.shp: No such file or directory
#   0%|          | 0/1185 [00:04<?, ?it/s]
# ressci201900060-RNC2-Coastal/Retrolens/Bay of Plenty/WaihiBeach/Shorelines/WaihiBeach_16NOV1942.shp: No such file or directory

# %%
bad = df[df.n_lines_now == 0]
bad[["filename", "n_lines", "n_lines_now"]]
# Out:
#                                                                                       filename  \
# 5                    Retrolens/Tasman/RuataniwhaInlet/Shorelines/RuataniwhaInlet_11OCT1950.shp
# 11                               Retrolens/Tasman/Totaranui/Shorelines/Totaranui_21FEB2002.shp
# 13                               Retrolens/Tasman/Totaranui/Shorelines/Totaranui_26JAN1974.shp
# 15                                 Retrolens/Tasman/SandyBay/Shorelines/SandyBay_19May1958.shp
# 69          6           0
# 70          7           0
# 71         15           0
# 75         15           0
# 77         12           0
# 78         12           0
# 79         10           0
# 455         3           0
# 456         8           0
# 467        12           0
# 470        11           0
# 471        11           0
# 507         7           0
# 510         5           0
# 511         8           0
# 1077        8           0

# %%
len(bad)
# Out:
# 34

# %%
def get_mtime(filename):
    return pd.to_datetime(os.path.getmtime(filename), unit="s", origin="unix", utc=True).tz_convert("Pacific/Auckland")
bad["mtime"] = bad.filename.apply(get_mtime)
bad[["filename", "n_lines", "n_lines_now", "mtime"]].sort_values("mtime")
# Out:
# /tmp/ipykernel_1023923/2623750301.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bad["mtime"] = bad.filename.apply(get_mtime)
#                                                                                       filename  \
# 1077  MaxarImagery/HighFreq/Southland/ToetoesBay_east/Shorelines/ToetoesBay_east_24NOV2019.shp
# 29                                Retrolens/Canterbury/GoreBay/Shorelines/GoreBay_3NOV1965.shp
# 16                                 Retrolens/Tasman/SandyBay/Shorelines/SandyBay_04May1944.shp
# 43                                 Retrolens/Tasman/SandyBay/Shorelines/SandyBay_21FEB2002.shp
# 42                                 Retrolens/Tasman/SandyBay/Shorelines/SandyBay_31JAN1980.shp
# 70                                   Retrolens/Tasman/Motueka/Shorelines/Motueka_19MAY1958.shp
# 63                           Retrolens/Tasman/PortPuponga/Shorelines/PortPuponga_16SEP1954.shp
# 62                           Retrolens/Tasman/PortPuponga/Shorelines/PortPuponga_20OCT1975.shp
# 54                               Retrolens/Tasman/WainuiBay/Shorelines/WainuiBay_31JAN1980.shp
# 44                                 Retrolens/Tasman/SandyBay/Shorelines/SandyBay_26JAN1974.shp
# 67                                       Retrolens/Tasman/Mapua/Shorelines/Mapua_22FEB1940.shp
# 56                               Retrolens/Tasman/WainuiBay/Shorelines/WainuiBay_02APR1973.shp
# 69                                   Retrolens/Tasman/Motueka/Shorelines/Motueka_27MAR1947.shp
# 68                                       Retrolens/Tasman/Mapua/Shorelines/Mapua_22SEP1969.shp
# 79                    Retrolens/Tasman/ TakakaRiver_North/Shorelines/TakakaRiver_21FEB2002.shp
# 71                            Retrolens/Tasman/ TorrentBay/Shorelines/TorrentBay_09APR1965.shp
# 78                    Retrolens/Tasman/ TakakaRiver_North/Shorelines/TakakaRiver_27MAR1938.shp
# 75                            Retrolens/Tasman/ TorrentBay/Shorelines/TorrentBay_26JAN1974.shp
# 77                    Retrolens/Tasman/ TakakaRiver_North/Shorelines/TakakaRiver_31JAN1980.shp
# 27                               Retrolens/Canterbury/GoreBay/Shorelines/GoreBay_25FEB1979.shp
# 5                    Retrolens/Tasman/RuataniwhaInlet/Shorelines/RuataniwhaInlet_11OCT1950.shp
# 15                                 Retrolens/Tasman/SandyBay/Shorelines/SandyBay_19May1958.shp
# 13                               Retrolens/Tasman/Totaranui/Shorelines/Totaranui_26JAN1974.shp
# 21                         Retrolens/Tasman/MoutereRiver/Shorelines/MoutereRiver_22FEB1940.shp
# 11                               Retrolens/Tasman/Totaranui/Shorelines/Totaranui_21FEB2002.shp
# 26                                Retrolens/Canterbury/GoreBay/Shorelines/GoreBay_7OCT1955.shp
#  'ressci201900060-RNC2-Coastal/Retrolens/Canterbury/GoochBay/Shorelines/GoochBay_10DEC1942.prj',
#  'ressci201900060-RNC2-Coastal/Retrolens/Canterbury/GoochBay/Shorelines/GoochBay_10DEC1942.cpg']

# %%
backup = gpd.read_file("shorelines.geojson")
backup.shape
# Out:
# (12485, 36)

# %%
test = gpd.read_file("Retrolens/Canterbury/GoochBay/Shorelines/GoochBay_8OCT1961.shp")
test
# Out:
#    Id      Region      Site        Date    DSASDate Digitiser  Scale Notes  \
# 0   0  Canterbury  GoochBay  1961-10-08  08/10/1961        TK   1500   EOV
# 1   0  Canterbury  GoochBay  1961-10-08  08/10/1961        TK   1500   EOV
# 2   0  Canterbury  GoochBay  1961-10-08  08/10/1961        TK   1500   EOV
# 3   0  Canterbury  GoochBay  1961-10-08  08/10/1961        TK   1500   EOV
#
#   Source  CPS  Proxy  Photoscale  Georef_ER  Pixel_Er  Total_UNCY  \
# 0     RL    2      1       44500        2.9       1.1    3.186362
# 1     RL    3      1       44500        2.9       1.1    3.249754
# 2     RL    4      1       44500        2.9       1.1    3.728927
# 3     RL    4      1       44500        2.9       1.1    3.728927
#
#                                                                                                                             geometry
# 0  LINESTRING (1651948.140 5303642.976, 1651944.568 5303640.198, 1651942.980 5303635.832, 1651939.805 5303634.245, 1651932.662 53...
# 1  LINESTRING (1651267.895 5303425.885, 1651265.116 5303420.726, 1651257.973 5303417.154, 1651250.035 5303416.757, 1651240.510 53...
# 2  LINESTRING (1654870.775 5304194.355, 1654877.521 5304193.164, 1654881.887 5304193.164, 1654886.650 5304191.973, 1654890.221 53...
# 3  LINESTRING (1652206.601 5303816.332, 1652220.492 5303809.585, 1652229.620 5303806.807, 1652238.351 5303802.838, 1652245.495 53...

# %%
cols = test.columns
cols
# Out:
# Index(['Id', 'Region', 'Site', 'Date', 'DSASDate', 'Digitiser', 'Scale',
#        'Notes', 'Source', 'CPS', 'Proxy', 'Photoscale', 'Georef_ER',
#        'Pixel_Er', 'Total_UNCY', 'geometry'],
#       dtype='object')

# %%
glob('Retrolens/Tasman/RuataniwhaInlet/Shorelines/RuataniwhaInlet_11OCT1950.*')
# Out:
# ['Retrolens/Tasman/RuataniwhaInlet/Shorelines/RuataniwhaInlet_11OCT1950.shp.xml',
#  'Retrolens/Tasman/RuataniwhaInlet/Shorelines/RuataniwhaInlet_11OCT1950.cpg',
#  'Retrolens/Tasman/RuataniwhaInlet/Shorelines/RuataniwhaInlet_11OCT1950.prj',
#  'Retrolens/Tasman/RuataniwhaInlet/Shorelines/RuataniwhaInlet_11OCT1950.shp',
#  'Retrolens/Tasman/RuataniwhaInlet/Shorelines/RuataniwhaInlet_11OCT1950.dbf',
#  'Retrolens/Tasman/RuataniwhaInlet/Shorelines/RuataniwhaInlet_11OCT1950.shx']

# %%
gpd.read_file('Retrolens/Tasman/RuataniwhaInlet/Shorelines/RuataniwhaInlet_11OCT1950.shp')
# Out:
# Empty GeoDataFrame
# Columns: [Id, Region, Site, Date, DSASDate, Digitiser, Scale, Notes, Source, CPS, Proxy, Photoscale, Georef_ER, Pixel_Er, Total_UNCY, geometry]
# Index: []

# %%
backup[backup.filename == "Retrolens/Canterbury/GoochBay/Shorelines/GoochBay_10DEC1942.shp"][cols].to_crs(2193).to_file("Retrolens/Canterbury/GoochBay/Shorelines/GoochBay_10DEC1942.shp")

# %%
backup[backup.filename == "Retrolens/Bay of Plenty/WaihiBeach/Shorelines/WaihiBeach_16NOV1942.shp"][cols].to_crs(2193).to_file("Retrolens/Bay of Plenty/WaihiBeach/Shorelines/WaihiBeach_16NOV1942.shp")

# %%
# Store the bad files in a zip, just in case
import os
import zipfile

zf = zipfile.ZipFile("bad.zip", "w")
for file in bad.filename:
    files = glob(os.path.splitext(file)[0] + "*")
    for f in files:
        print(f)
        zf.write(f)
zf.close()
# Out:
# Retrolens/Tasman/RuataniwhaInlet/Shorelines/RuataniwhaInlet_11OCT1950.shp.xml
# Retrolens/Tasman/RuataniwhaInlet/Shorelines/RuataniwhaInlet_11OCT1950.cpg
# Retrolens/Tasman/RuataniwhaInlet/Shorelines/RuataniwhaInlet_11OCT1950.prj
# Retrolens/Tasman/RuataniwhaInlet/Shorelines/RuataniwhaInlet_11OCT1950.shp
# Retrolens/Tasman/RuataniwhaInlet/Shorelines/RuataniwhaInlet_11OCT1950.dbf
# Retrolens/Tasman/RuataniwhaInlet/Shorelines/RuataniwhaInlet_11OCT1950.shx
# Retrolens/Tasman/Totaranui/Shorelines/Totaranui_21FEB2002.shx
# Retrolens/Tasman/Totaranui/Shorelines/Totaranui_21FEB2002.prj
# Retrolens/Tasman/Totaranui/Shorelines/Totaranui_21FEB2002.dbf
# Retrolens/Tasman/Totaranui/Shorelines/Totaranui_21FEB2002.shp.xml
# Retrolens/Tasman/Totaranui/Shorelines/Totaranui_21FEB2002.cpg
# Retrolens/Tasman/Totaranui/Shorelines/Totaranui_21FEB2002.shp
# Retrolens/Tasman/Totaranui/Shorelines/Totaranui_26JAN1974.prj
# Retrolens/Tasman/Totaranui/Shorelines/Totaranui_26JAN1974.shx
# Retrolens/Tasman/Totaranui/Shorelines/Totaranui_26JAN1974.shp
# Retrolens/Tasman/Totaranui/Shorelines/Totaranui_26JAN1974.cpg
# Retrolens/Tasman/Totaranui/Shorelines/Totaranui_26JAN1974.shp.xml
# Retrolens/Tasman/Totaranui/Shorelines/Totaranui_26JAN1974.dbf
# Retrolens/Tasman/SandyBay/Shorelines/SandyBay_19May1958.dbf
# Retrolens/Tasman/SandyBay/Shorelines/SandyBay_19May1958.shx
# Retrolens/Tasman/SandyBay/Shorelines/SandyBay_19May1958.cpg
# Retrolens/Tasman/SandyBay/Shorelines/SandyBay_19May1958.shp.xml
# Retrolens/Tasman/SandyBay/Shorelines/SandyBay_19May1958.shp
# Retrolens/Tasman/SandyBay/Shorelines/SandyBay_19May1958.prj
# Retrolens/Tasman/SandyBay/Shorelines/SandyBay_04May1944.prj
# Retrolens/Tasman/SandyBay/Shorelines/SandyBay_04May1944.shp.xml
# Retrolens/Tasman/SandyBay/Shorelines/SandyBay_04May1944.shx
# Retrolens/Tasman/SandyBay/Shorelines/SandyBay_04May1944.cpg
# Retrolens/Wellington/KapitiMid/Shorelines/KapitiMid_19JAN2006.cpg
# Retrolens/Wellington/KapitiMid/Shorelines/KapitiMid_19JAN2006.prj
# Retrolens/Wellington/KapitiMid/Shorelines/KapitiMid_19JAN2006.shp.xml
# Retrolens/Wellington/KapitiMid/Shorelines/KapitiMid_19JAN2006.dbf
# Retrolens/Wellington/KapitiMid/Shorelines/KapitiMid_19JAN2006.shx
# Retrolens/Bay of Plenty/PapateaBay/Shorelines/PapateaBay_1OCT1980.shx
# Retrolens/Bay of Plenty/PapateaBay/Shorelines/PapateaBay_1OCT1980.shp.xml
# Retrolens/Bay of Plenty/PapateaBay/Shorelines/PapateaBay_1OCT1980.cpg
# Retrolens/Bay of Plenty/PapateaBay/Shorelines/PapateaBay_1OCT1980.dbf
# Retrolens/Bay of Plenty/PapateaBay/Shorelines/PapateaBay_1OCT1980.shp
# Retrolens/Bay of Plenty/PapateaBay/Shorelines/PapateaBay_1OCT1980.prj
# Retrolens/Bay of Plenty/WaihiBeach/Shorelines/WaihiBeach_8FEB1991.cpg
# Retrolens/Bay of Plenty/WaihiBeach/Shorelines/WaihiBeach_8FEB1991.shp.xml
# Retrolens/Bay of Plenty/WaihiBeach/Shorelines/WaihiBeach_8FEB1991.shx
# Retrolens/Bay of Plenty/WaihiBeach/Shorelines/WaihiBeach_8FEB1991.prj
# Retrolens/Bay of Plenty/WaihiBeach/Shorelines/WaihiBeach_8FEB1991.dbf
# Retrolens/Bay of Plenty/WaihiBeach/Shorelines/WaihiBeach_8FEB1991.shp
# Retrolens/Bay of Plenty/WaihiBeach/Shorelines/WaihiBeach_12APR1975.shp.xml
# Retrolens/Bay of Plenty/WaihiBeach/Shorelines/WaihiBeach_12APR1975.prj
# Retrolens/Bay of Plenty/WaihiBeach/Shorelines/WaihiBeach_12APR1975.shx
# Retrolens/Bay of Plenty/WaihiBeach/Shorelines/WaihiBeach_12APR1975.dbf
# Retrolens/Bay of Plenty/WaihiBeach/Shorelines/WaihiBeach_12APR1975.shp
# Retrolens/Bay of Plenty/WaihiBeach/Shorelines/WaihiBeach_12APR1975.cpg
# MaxarImagery/HighFreq/Southland/ToetoesBay_east/Shorelines/ToetoesBay_east_24NOV2019.shp.xml
# MaxarImagery/HighFreq/Southland/ToetoesBay_east/Shorelines/ToetoesBay_east_24NOV2019.prj
# MaxarImagery/HighFreq/Southland/ToetoesBay_east/Shorelines/ToetoesBay_east_24NOV2019.shx
# MaxarImagery/HighFreq/Southland/ToetoesBay_east/Shorelines/ToetoesBay_east_24NOV2019.cpg
# MaxarImagery/HighFreq/Southland/ToetoesBay_east/Shorelines/ToetoesBay_east_24NOV2019.dbf
# MaxarImagery/HighFreq/Southland/ToetoesBay_east/Shorelines/ToetoesBay_east_24NOV2019.shp

# %%
for f in tqdm(bad.filename):
    print(f"Restoring {f} from backup")
    backup_copy = backup[backup.filename == f][cols].to_crs(2193)
    backup_copy.to_file(f)
# Out:
#   0%|          | 0/34 [00:00<?, ?it/s]
# Restoring Retrolens/Tasman/RuataniwhaInlet/Shorelines/RuataniwhaInlet_11OCT1950.shp from backup
# Restoring Retrolens/Tasman/Totaranui/Shorelines/Totaranui_21FEB2002.shp from backup
# Restoring Retrolens/Tasman/Totaranui/Shorelines/Totaranui_26JAN1974.shp from backup
# Restoring Retrolens/Tasman/SandyBay/Shorelines/SandyBay_19May1958.shp from backup
# Restoring Retrolens/Tasman/SandyBay/Shorelines/SandyBay_04May1944.shp from backup
# Restoring Retrolens/Tasman/MoutereRiver/Shorelines/MoutereRiver_22FEB1940.shp from backup
# Restoring Retrolens/Canterbury/GoreBay/Shorelines/GoreBay_7OCT1955.shp from backup
# Restoring Retrolens/Canterbury/GoreBay/Shorelines/GoreBay_25FEB1979.shp from backup
# Restoring Retrolens/Canterbury/GoreBay/Shorelines/GoreBay_3NOV1965.shp from backup
# Restoring Retrolens/Tasman/SandyBay/Shorelines/SandyBay_31JAN1980.shp from backup
# Restoring Retrolens/Tasman/SandyBay/Shorelines/SandyBay_21FEB2002.shp from backup
# Restoring Retrolens/Tasman/SandyBay/Shorelines/SandyBay_26JAN1974.shp from backup
# Restoring Retrolens/Tasman/WainuiBay/Shorelines/WainuiBay_31JAN1980.shp from backup
# Restoring Retrolens/Tasman/WainuiBay/Shorelines/WainuiBay_02APR1973.shp from backup
# Restoring Retrolens/Tasman/PortPuponga/Shorelines/PortPuponga_20OCT1975.shp from backup
# Restoring Retrolens/Tasman/PortPuponga/Shorelines/PortPuponga_16SEP1954.shp from backup
# Restoring Retrolens/Tasman/Mapua/Shorelines/Mapua_22FEB1940.shp from backup
# Restoring Retrolens/Tasman/Mapua/Shorelines/Mapua_22SEP1969.shp from backup
# Restoring Retrolens/Tasman/Motueka/Shorelines/Motueka_27MAR1947.shp from backup
# Restoring Retrolens/Tasman/Motueka/Shorelines/Motueka_19MAY1958.shp from backup
# Restoring Retrolens/Tasman/ TorrentBay/Shorelines/TorrentBay_09APR1965.shp from backup
# Restoring Retrolens/Tasman/ TorrentBay/Shorelines/TorrentBay_26JAN1974.shp from backup
# Restoring Retrolens/Tasman/ TakakaRiver_North/Shorelines/TakakaRiver_31JAN1980.shp from backup
# Restoring Retrolens/Tasman/ TakakaRiver_North/Shorelines/TakakaRiver_27MAR1938.shp from backup
# Restoring Retrolens/Tasman/ TakakaRiver_North/Shorelines/TakakaRiver_21FEB2002.shp from backup
# Restoring Retrolens/Bay of Plenty/RangitaikiRiver/Shorelines/RangitaikiRiver_14DEC1982.shp from backup
# Restoring Retrolens/Bay of Plenty/KohioawaBeach/Shorelines/KohioawaBeach_26APR1974.shp from backup
# Restoring Retrolens/Wellington/KapitiMid/Shorelines/KapitiMid_31OCT2019.shp from backup
# Restoring Retrolens/Wellington/KapitiMid/Shorelines/KapitiMid_25AUG2017.shp from backup
# Restoring Retrolens/Wellington/KapitiMid/Shorelines/KapitiMid_19JAN2006.shp from backup
# Restoring Retrolens/Bay of Plenty/PapateaBay/Shorelines/PapateaBay_1OCT1980.shp from backup
# Restoring Retrolens/Bay of Plenty/WaihiBeach/Shorelines/WaihiBeach_8FEB1991.shp from backup
